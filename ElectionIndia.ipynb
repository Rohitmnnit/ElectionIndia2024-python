# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('GE_2024_Results.csv')
df
# Out:
#         ID                      State               Constituency  \
# 0        1  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 1        2  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 2        3  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 3        4  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 4        5  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# ...    ...                        ...                        ...
# 8897  8898                West Bengal                   Uluberia
# 8898  8899                West Bengal                   Uluberia
# 8899  8900                West Bengal                   Uluberia
# 8900  8901                West Bengal                   Uluberia
# 8901  8902                West Bengal                   Uluberia
#
#                Candidate                                        Party  \
# 0        BISHNU PADA RAY                       Bharatiya Janata Party
# 1     KULDEEP RAI SHARMA                     Indian National Congress
# 2             MANOJ PAUL          Andaman Nicobar Democratic Congress
# 3             D AYYAPPAN          Communist Party of India  (Marxist)
# 4        V.K. ABDUL AZIZ                                  Independent
# ...                  ...                                          ...
# 8897     SK. SAPIYAR ALI                                  Independent
# 8898         NIKHIL BERA  Socialist Unity Centre Of India (COMMUNIST)
# 8899   AMAL KUMAR BARMAN                                  Independent
# 8900    RAMPRASAD GHORAI                          Indian Unity Centre
# 8901                NOTA                            None of the Above
#
#      EVM Votes Postal Votes  Total Votes % of Votes Result
# 0       102182          254       102436      50.58    Won
# 1        77829          211        78040      38.54   Lost
# 2         8236           18         8254       4.08   Lost
# 3         6009            8         6017       2.97   Lost
# 4         2195            8         2203       1.09   Lost
# ...        ...          ...          ...        ...    ...
# 8897      2924            -         2924       0.21   Lost
# 8898      2095           12         2107       0.15   Lost
# 8899      1997            3         2000       0.14   Lost
# 8900      1568            4         1572       0.11   Lost
# 8901     11263           55        11318       0.81   Lost
#
# [8902 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8902 entries, 0 to 8901
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            8902 non-null   int64
#  1   State         8902 non-null   object
#  2   Constituency  8902 non-null   object
#  3   Candidate     8902 non-null   object
#  4   Party         8902 non-null   object
#  5   EVM Votes     8902 non-null   object
#  6   Postal Votes  8902 non-null   object
#  7   Total Votes   8902 non-null   int64
#  8   % of Votes    8902 non-null   object
#  9   Result        8902 non-null   object
# dtypes: int64(2), object(8)
# memory usage: 695.6+ KB

# %%
df.isnull().sum()
# Out:
# ID              0
# State           0
# Constituency    0
# Candidate       0
# Party           0
# EVM Votes       0
# Postal Votes    0
# Total Votes     0
# % of Votes      0
# Result          0
# dtype: int64

# %%
df['EVM Votes'] = df['EVM Votes'].str.replace('-', '0')
df['Postal Votes'] = df['Postal Votes'].str.replace('-', '0')
df['% of Votes'] = df['% of Votes'].str.replace('-', '0')

new_datatype={'EVM Votes':'int64','Postal Votes':'int64','% of Votes':'float64'}
df=df.astype(new_datatype)

# %%
df
# Out:
#         ID                      State               Constituency  \
# 0        1  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 1        2  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 2        3  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 3        4  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 4        5  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# ...    ...                        ...                        ...
# 8897  8898                West Bengal                   Uluberia
# 8898  8899                West Bengal                   Uluberia
# 8899  8900                West Bengal                   Uluberia
# 8900  8901                West Bengal                   Uluberia
# 8901  8902                West Bengal                   Uluberia
#
#                Candidate                                        Party  \
# 0        BISHNU PADA RAY                       Bharatiya Janata Party
# 1     KULDEEP RAI SHARMA                     Indian National Congress
# 2             MANOJ PAUL          Andaman Nicobar Democratic Congress
# 3             D AYYAPPAN          Communist Party of India  (Marxist)
# 4        V.K. ABDUL AZIZ                                  Independent
# ...                  ...                                          ...
# 8897     SK. SAPIYAR ALI                                  Independent
# 8898         NIKHIL BERA  Socialist Unity Centre Of India (COMMUNIST)
# 8899   AMAL KUMAR BARMAN                                  Independent
# 8900    RAMPRASAD GHORAI                          Indian Unity Centre
# 8901                NOTA                            None of the Above
#
#       EVM Votes  Postal Votes  Total Votes  % of Votes Result
# 0        102182           254       102436       50.58    Won
# 1         77829           211        78040       38.54   Lost
# 2          8236            18         8254        4.08   Lost
# 3          6009             8         6017        2.97   Lost
# 4          2195             8         2203        1.09   Lost
# ...         ...           ...          ...         ...    ...
# 8897       2924             0         2924        0.21   Lost
# 8898       2095            12         2107        0.15   Lost
# 8899       1997             3         2000        0.14   Lost
# 8900       1568             4         1572        0.11   Lost
# 8901      11263            55        11318        0.81   Lost
#
# [8902 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8902 entries, 0 to 8901
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            8902 non-null   int64
#  1   State         8902 non-null   object
#  2   Constituency  8902 non-null   object
#  3   Candidate     8902 non-null   object
#  4   Party         8902 non-null   object
#  5   EVM Votes     8902 non-null   int64
#  6   Postal Votes  8902 non-null   int64
#  7   Total Votes   8902 non-null   int64
#  8   % of Votes    8902 non-null   float64
#  9   Result        8902 non-null   object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 695.6+ KB

# %%
#What is the total number of candidates across all constituencies?
df['Candidate'].count()
# Out:
# 8902

# %%
#How many constituencies are there in total?
df['Constituency'].drop_duplicates().count()
# Out:
# 541

# %%
# What is the average voter turnout (total votes) per constituency across the entire dataset?
df.groupby('Constituency')['Total Votes'].mean().sort_values(ascending=False).to_frame()
# Out:
#                              Total Votes
# Constituency
# Bardoli                    334833.250000
# Dibrugarh                  319580.500000
# Jorhat                     278232.000000
# KHARGONE                   259796.333333
# Nabarangpur                248495.000000
# ...                                  ...
# KARUR                       20582.636364
# Andaman & Nicobar Islands   15578.000000
# Daman & Diu                 11551.250000
# Lakshadweep                  9840.000000
# Surat                           0.000000
#
# [541 rows x 1 columns]

# %%
#which party recieved the highest number of total votes?
df.groupby('Party')['Total Votes'].max().sort_values(ascending=False).to_frame().reset_index().head(1)
# Out:
#                       Party  Total Votes
# 0  Indian National Congress      1471885

# %%
#which party won the most number of seats?
win=df[df['Result']=='Won']
win.groupby('Party').count()['ID'].sort_values(ascending=False).head(1)
# Out:
# Party
# Bharatiya Janata Party    240
# Name: ID, dtype: int64

# %%
#what is distribution of seats won by each party?
dist_party=win.groupby('Party').count().reset_index().sort_values(by='ID',ascending=False)[["Party","Result"]].rename(columns={'Result':'Seats'})
dist_party.set_index('Party')
# Out:
#                                                     Seats
# Party
# Bharatiya Janata Party                                240
# Indian National Congress                               99
# Samajwadi Party                                        37
# All India Trinamool Congress                           29
# Dravida Munnetra Kazhagam                              22
# Telugu Desam                                           16
# Janata Dal  (United)                                   12
# Shiv Sena (Uddhav Balasaheb Thackrey)                   9
# Nationalist Congress Party – Sharadchandra Pawar        8
# Shiv Sena                                               7
# Independent                                             7
# Lok Janshakti Party(Ram Vilas)                          5
# Rashtriya Janata Dal                                    4
# Yuvajana Sramika Rythu Congress Party                   4
# Communist Party of India  (Marxist)                     4
# Indian Union Muslim League                              3
# Aam Aadmi Party                                         3
# Jharkhand Mukti Morcha                                  3
# Janasena Party                                          2
# Janata Dal  (Secular)                                   2
# Jammu & Kashmir National Conference                     2
# Communist Party of India  (Marxist-Leninist)  (...      2
# Communist Party of India                                2
# Viduthalai Chiruthaigal Katchi                          2
# Rashtriya Lok Dal                                       2
# Revolutionary Socialist Party                           1
# Sikkim Krantikari Morcha                                1
# Shiromani Akali Dal                                     1
# United People’s Party, Liberal                          1
# Voice of the People Party                               1
# AJSU Party                                              1
# Rashtriya Loktantrik Party                              1
# Nationalist Congress Party                              1
# Marumalarchi Dravida Munnetra Kazhagam                  1
# Kerala Congress                                         1
# Hindustani Awam Morcha (Secular)                        1
# Bharat Adivasi Party                                    1
# Asom Gana Parishad                                      1
# Apna Dal (Soneylal)                                     1
# All India Majlis-E-Ittehadul Muslimeen                  1
# Aazad Samaj Party (Kanshi Ram)                          1
# Zoram People’s Movement                                 1

# %%
dist_party.plot(kind='bar',x='Party',y='Seats',figsize=(15,7))
plt.ylabel('No. of seats won by party')
plt.xlabel('Name of party')
plt.title('No. of seats VS party')
plt.show()

# %%
# the top 10 candidates based on the total votes received
win.groupby('Candidate')['Total Votes'].max().sort_values(ascending=False).reset_index().head(10)
# Out:
#                Candidate  Total Votes
# 0        RAKIBUL HUSSAIN      1471885
# 1        SHANKAR LALWANI      1226751
# 2  SHIVRAJ SINGH CHOUHAN      1116460
# 3       DR C N MANJUNATH      1079002
# 4      BRIJMOHAN AGRAWAL      1050351
# 5      ABHISHEK BANERJEE      1048230
# 6              C R PATIL      1031065
# 7              AMIT SHAH      1010972
# 8        EATALA RAJENDER       991042
# 9      SHOBHA KARANDLAJE       986049

# %%
# candidate won their seats by the largest margins
win= df[df['Result'] == 'Won'].copy()
win['% of Votes'] = pd.to_numeric(win['% of Votes'], errors='coerce')
win.loc[:, 'Margin'] = win['Total Votes'] * (win['% of Votes'] / 100)
largest_margin_candidate = win.loc[win['Margin'].idxmax()]
largest_margin_candidate[['Candidate', 'Party', 'Margin']]
# Out:
# Candidate           SHANKAR LALWANI
# Party        Bharatiya Janata Party
# Margin                  963490.2354
# Name: 3289, dtype: object

# %%
win
# Out:
#         ID                      State               Constituency  \
# 0        1  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 13      14             Andhra Pradesh            Amalapuram (SC)
# 29      30             Andhra Pradesh                 Anakapalle
# 45      46             Andhra Pradesh                 Ananthapur
# 67      68             Andhra Pradesh                 Araku (ST)
# ...    ...                        ...                        ...
# 8838  8839                West Bengal                    Raiganj
# 8859  8860                West Bengal                   Ranaghat
# 8867  8868                West Bengal                  Srerampur
# 8879  8880                West Bengal                     Tamluk
# 8889  8890                West Bengal                   Uluberia
#
#                              Candidate                                  Party  \
# 0                      BISHNU PADA RAY                 Bharatiya Janata Party
# 13               G M HARISH (BALAYOGI)                           Telugu Desam
# 29                          C.M.RAMESH                 Bharatiya Janata Party
# 45    AMBICA G LAKSHMINARAYANA VALMIKI                           Telugu Desam
# 67                  GUMMA THANUJA RANI  Yuvajana Sramika Rythu Congress Party
# ...                                ...                                    ...
# 8838              KARTICK CHANDRA PAUL                 Bharatiya Janata Party
# 8859                  JAGANNATH SARKAR                 Bharatiya Janata Party
# 8867                   KALYAN BANERJEE           All India Trinamool Congress
# 8879              ABHIJIT GANGOPADHYAY                 Bharatiya Janata Party
# 8889                       SAJDA AHMED           All India Trinamool Congress
#
#       EVM Votes  Postal Votes  Total Votes  % of Votes Result       Margin
# 0        102182           254       102436       50.58    Won   51812.1288
# 13       786149         10832       796981       61.25    Won  488150.8625
# 29       750027         12042       762069       57.50    Won  438189.6750
# 45       755862         12383       768245       53.33    Won  409705.0585
# 67       471470          5535       477005       40.96    Won  195381.2480
# ...         ...           ...          ...         ...    ...          ...
# 8838     558644          2253       560897       40.99    Won  229911.6803
# 8859     778046          4350       782396       50.78    Won  397300.6888
# 8867     671865          2105       673970       45.65    Won  307667.3050
# 8879     761183          4401       765584       48.54    Won  371614.4736
# 8889     722586          2036       724622       52.10    Won  377528.0620
#
# [543 rows x 11 columns]

# %%
#the top 10 closest races(smallest margins)?
smallest_margins=win['Margin'].sort_values(ascending=True).reset_index().head(10)
# win[win['index'].isin(smallest_margins['index'])]
smallest_margins['Margin']
# Out:
# 0        0.0000
# 1    13452.1254
# 2    19569.0846
# 3    31422.2085
# 4    51812.1288
# 5    63190.3620
# 6    65526.0081
# 7    70213.5316
# 8    71300.4786
# 9    71910.0058
# Name: Margin, dtype: float64

# %%
#total number of votes in every states
df.groupby('State')['Total Votes'].sum().sort_values(ascending=False).reset_index()
# Out:
#                                    State  Total Votes
# 0                          Uttar Pradesh     87911642
# 1                            West Bengal     60483687
# 2                            Maharashtra     57179133
# 3                             Tamil Nadu     43674048
# 4                                  Bihar     43448949
# 5                              Karnataka     38793617
# 6                         Madhya Pradesh     37940251
# 7                         Andhra Pradesh     33729342
# 8                              Rajasthan     33164877
# 9                                Gujarat     29115599
# 10                                Odisha     25129026
# 11                             Telangana     22008373
# 12                                 Assam     20059870
# 13                                Kerala     19980436
# 14                             Jharkhand     17241982
# 15                          Chhattisgarh     15061348
# 16                                Punjab     13530923
# 17                               Haryana     13055572
# 18                          NCT OF Delhi      8938049
# 19                     Jammu and Kashmir      5151193
# 20                           Uttarakhand      4836608
# 21                      Himachal Pradesh      4069906
# 22                               Tripura      2344154
# 23                             Meghalaya      1711967
# 24                               Manipur      1593632
# 25                                   Goa       906538
# 26                            Puducherry       807940
# 27                              Nagaland       760796
# 28                     Arunachal Pradesh       723247
# 29                               Mizoram       491336
# 30                            Chandigarh       449275
# 31                                Sikkim       384893
# 32  Dadra & Nagar Haveli and Daman & Diu       297998
# 33             Andaman & Nicobar Islands       202514
# 34                                Ladakh       135524
# 35                           Lakshadweep        49200

# %%
# state had the highest voter turnout
df.groupby('State')['Total Votes'].sum().sort_values(ascending=False).reset_index().head(1).rename(columns={'Total Votes':'Highest Voter Turnout'})
# Out:
#            State  Highest Voter Turnout
# 0  Uttar Pradesh               87911642

# %%
#different parties perform in every state
df.groupby(['State','Party']).agg({'Candidate':'count','Total Votes':'sum'}).rename(columns={'Candidate': 'Seats Won'}).reset_index()
# Out:
#                           State                                        Party  \
# 0     Andaman & Nicobar Islands     All India Anna Dravida Munnetra Kazhagam
# 1     Andaman & Nicobar Islands          Andaman Nicobar Democratic Congress
# 2     Andaman & Nicobar Islands                          Bahujan Samaj Party
# 3     Andaman & Nicobar Islands                       Bharatiya Janata Party
# 4     Andaman & Nicobar Islands          Communist Party of India  (Marxist)
# ...                         ...                                          ...
# 1331                West Bengal                Revolutionary Socialist Party
# 1332                West Bengal                        Right to Recall Party
# 1333                West Bengal             Social Democratic Party Of India
# 1334                West Bengal  Socialist Unity Centre Of India (COMMUNIST)
# 1335                West Bengal         The National Road Map Party of India
#
#       Seats Won  Total Votes
# 0             1          914
# 1             1         8254
# 2             1          719
# 3             1       102436
# 4             1         6017
# ...         ...          ...
# 1331          3       134039
# 1332          1         1544
# 1333          5        11668
# 1334         42       165474
# 1335          1         2418
#
# [1336 rows x 4 columns]

# %%
#number of seats won by top 5 parties
dist_party=win.groupby('Party').count().reset_index().sort_values(by='ID',ascending=False)[["Party","Result"]].rename(columns={'Result':'Seats'}).head(5)
dist_party.set_index('Party').reset_index()
dist_party.plot(kind='bar',x='Party',y='Seats',color=('red','green','orange','yellow','brown'))
plt.xlabel('top 5 Parties')
plt.ylabel('Number of seats')
plt.title('Top five party analysis on the basis of no. of seats')
# Out:
# Text(0.5, 1.0, 'Top five party analysis on the basis of no. of seats')

# %%
#total number of votes in across each states
votes_state=df.groupby('State')['Total Votes'].sum().sort_values(ascending=False).reset_index()
votes_state.plot(kind='bar',y='Total Votes',x='State',figsize=(15,7))
plt.xlabel('states')
plt.ylabel('total votes')
plt.title('total votes across each state')
plt.show()

# %%
#a pie chart representing the percentage of total votes received by each major party
major_parties=df.groupby('Party')['Total Votes'].sum().reset_index().sort_values(by='Total Votes',ascending=False).head(5)
plt.figure(figsize=(10, 7))
plt.pie(major_parties['Total Votes'], labels=major_parties['Party'], autopct='%1.1f%%', startangle=140)
plt.title('Percentage of Total Votes Received by Each Major Party')
plt.axis('equal')  # Equal aspect ratio ensures the pie is drawn as a circle.
plt.show()

# %%
win
# Out:
#         ID                      State               Constituency  \
# 0        1  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 13      14             Andhra Pradesh            Amalapuram (SC)
# 29      30             Andhra Pradesh                 Anakapalle
# 45      46             Andhra Pradesh                 Ananthapur
# 67      68             Andhra Pradesh                 Araku (ST)
# ...    ...                        ...                        ...
# 8838  8839                West Bengal                    Raiganj
# 8859  8860                West Bengal                   Ranaghat
# 8867  8868                West Bengal                  Srerampur
# 8879  8880                West Bengal                     Tamluk
# 8889  8890                West Bengal                   Uluberia
#
#                              Candidate                                  Party  \
# 0                      BISHNU PADA RAY                 Bharatiya Janata Party
# 13               G M HARISH (BALAYOGI)                           Telugu Desam
# 29                          C.M.RAMESH                 Bharatiya Janata Party
# 45    AMBICA G LAKSHMINARAYANA VALMIKI                           Telugu Desam
# 67                  GUMMA THANUJA RANI  Yuvajana Sramika Rythu Congress Party
# ...                                ...                                    ...
# 8838              KARTICK CHANDRA PAUL                 Bharatiya Janata Party
# 8859                  JAGANNATH SARKAR                 Bharatiya Janata Party
# 8867                   KALYAN BANERJEE           All India Trinamool Congress
# 8879              ABHIJIT GANGOPADHYAY                 Bharatiya Janata Party
# 8889                       SAJDA AHMED           All India Trinamool Congress
#
#       EVM Votes  Postal Votes  Total Votes  % of Votes Result       Margin
# 0        102182           254       102436       50.58    Won   51812.1288
# 13       786149         10832       796981       61.25    Won  488150.8625
# 29       750027         12042       762069       57.50    Won  438189.6750
# 45       755862         12383       768245       53.33    Won  409705.0585
# 67       471470          5535       477005       40.96    Won  195381.2480
# ...         ...           ...          ...         ...    ...          ...
# 8838     558644          2253       560897       40.99    Won  229911.6803
# 8859     778046          4350       782396       50.78    Won  397300.6888
# 8867     671865          2105       673970       45.65    Won  307667.3050
# 8879     761183          4401       765584       48.54    Won  371614.4736
# 8889     722586          2036       724622       52.10    Won  377528.0620
#
# [543 rows x 11 columns]

# %%
#relation between EVM Votes and Postal Votes for the winning candidate
win_cd=win[['EVM Votes','Postal Votes']]
win_cd
# Out:
#       EVM Votes  Postal Votes
# 0        102182           254
# 13       786149         10832
# 29       750027         12042
# 45       755862         12383
# 67       471470          5535
# ...         ...           ...
# 8838     558644          2253
# 8859     778046          4350
# 8867     671865          2105
# 8879     761183          4401
# 8889     722586          2036
#
# [543 rows x 2 columns]

# %%
sns.scatterplot(data=win,x='EVM Votes',y='Postal Votes')
# Out:
# <Axes: xlabel='EVM Votes', ylabel='Postal Votes'>
